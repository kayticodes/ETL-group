# %%
# Import Dependencies
import pandas as pd
from sqlalchemy import create_engine
import requests
import time
from datetime import date
import calendar
import grequests
import time
from datetime import date
import calendar
from config import key
import json
# Out:
# C:\Users\dsiddine\AppData\Local\Continuum\anaconda3\lib\site-packages\gevent\hub.py:154: UserWarning: libuv only supports millisecond timer resolution; all times less will be set to 1 ms
#   with loop.timer(seconds, ref=ref) as t:

# %% [markdown]
# # Music csv file

# %%
music_file = "music_data.csv"
music_data_df = pd.read_csv(music_file)

music_data_df.head()
# Out:
#    Position                  Track Name         Artist  Streams  \
# 0         1  Reggaetón Lento (Bailemos)           CNCO    19272
# 1         2                    Chantaje        Shakira    19270
# 2         3   Otra Vez (feat. J Balvin)  Zion & Lennox    15761
# 3         4                Vente Pa' Ca   Ricky Martin    14954
# 4         5                      Safari       J Balvin    14269
#
#                                                  URL        Date Region
# 0  https://open.spotify.com/track/3AEZUABDXNtecAO...  2017-01-01     ec
# 1  https://open.spotify.com/track/6mICuAdrwEjh6Y6...  2017-01-01     ec
# 2  https://open.spotify.com/track/3QwBODjSEzelZyV...  2017-01-01     ec
# 3  https://open.spotify.com/track/7DM4BPaS7uofFul...  2017-01-01     ec
# 4  https://open.spotify.com/track/6rQSrBHf7HlZjtc...  2017-01-01     ec
# C:\Users\dsiddine\AppData\Local\Continuum\anaconda3\lib\site-packages\gevent\hub.py:154: UserWarning: libuv only supports millisecond timer resolution; all times less will be set to 1 ms
#   with loop.timer(seconds, ref=ref) as t:

# %%
music_data_df = music_data_df.rename(columns = {'Region':'country_codes'})
music_data_df['country_codes'] = music_data_df['country_codes'].str.upper()
music_data_df.head()
# Out:
#    Position                  Track Name         Artist  Streams  \
# 0         1  Reggaetón Lento (Bailemos)           CNCO    19272
# 1         2                    Chantaje        Shakira    19270
# 2         3   Otra Vez (feat. J Balvin)  Zion & Lennox    15761
# 3         4                Vente Pa' Ca   Ricky Martin    14954
# 4         5                      Safari       J Balvin    14269
#
#                                                  URL        Date country_codes
# 0  https://open.spotify.com/track/3AEZUABDXNtecAO...  2017-01-01            EC
# 1  https://open.spotify.com/track/6mICuAdrwEjh6Y6...  2017-01-01            EC
# 2  https://open.spotify.com/track/3QwBODjSEzelZyV...  2017-01-01            EC
# 3  https://open.spotify.com/track/7DM4BPaS7uofFul...  2017-01-01            EC
# 4  https://open.spotify.com/track/6rQSrBHf7HlZjtc...  2017-01-01            EC
# C:\Users\dsiddine\AppData\Local\Continuum\anaconda3\lib\site-packages\gevent\hub.py:154: UserWarning: libuv only supports millisecond timer resolution; all times less will be set to 1 ms
#   with loop.timer(seconds, ref=ref) as t:

# %% [markdown]
# # Country codes web scraping

# %%
url = 'https://www.worldatlas.com/aatlas/ctycodes.htm'
# Out:
# C:\Users\dsiddine\AppData\Local\Continuum\anaconda3\lib\site-packages\gevent\hub.py:154: UserWarning: libuv only supports millisecond timer resolution; all times less will be set to 1 ms
#   with loop.timer(seconds, ref=ref) as t:

# %%
tables = pd.read_html(url)
tables
# Out:
# [                                        0         1        2         3  \
#  0                                 COUNTRY  A2 (ISO)  A3 (UN)  NUM (UN)
#  1                             Afghanistan        AF      AFG         4
#  2                                 Albania        AL      ALB         8
#  3                                 Algeria        DZ      DZA        12
#  4                          American Samoa        AS      ASM        16
#  5                                 Andorra        AD      AND        20
#  6                                  Angola        AO      AGO        24
#  7                                Anguilla        AI      AIA       660
#  8                              Antarctica        AQ      ATA        10
#  9                     Antigua and Barbuda        AG      ATG        28
#  10                              Argentina        AR      ARG        32
#  11                                Armenia        AM      ARM        51
#  12                                  Aruba        AW      ABW       533
#  13                              Australia        AU      AUS        36
#  14                                Austria        AT      AUT        40
#  15                             Azerbaijan        AZ      AZE        31
#  16                                Bahamas        BS      BHS        44
#  17                                Bahrain        BH      BHR        48
#  18                             Bangladesh        BD      BGD        50
#  19                               Barbados        BB      BRB        52
#  20                                Belarus        BY      BLR       112
#  21                                Belgium        BE      BEL        56
#  22                                 Belize        BZ      BLZ        84
#  23                                  Benin        BJ      BEN       204
#  24                                Bermuda        BM      BMU        60
#  25                                 Bhutan        BT      BTN        64
#  26                                Bolivia        BO      BOL        68
#  27                                Bonaire        BQ      BES       535
#  28                 Bosnia and Herzegovina        BA      BIH        70
#  29                               Botswana        BW      BWA        72
#  ..                                    ...       ...      ...       ...
#  219           United Republic of Tanzania        TZ      TZA       834
#  220                              Thailand        TH      THA       764
#  221                           Timor-Leste        TL      TLS       626
#  222                                  Togo        TG      TGO       768
#  223                               Tokelau        TK      TKL       772
#  224                                 Tonga        TO      TON       776
#  225                   Trinidad and Tobago        TT      TTO       780
#  226                               Tunisia        TN      TUN       788
#  227                                Turkey        TR      TUR       792
#  228                          Turkmenistan        TM      TKM       795
#  229              Turks and Caicos Islands        TC      TCA       796
#  230                                Tuvalu        TV      TUV       798
#  231                                Uganda        UG      UGA       800
#  232                               Ukraine        UA      UKR       804
#  233                  United Arab Emirates        AE      ARE       784
#  234                        United Kingdom        GB      GBR       826
#  235                         United States        US      USA       840
#  236  United States Minor Outlying Islands        UM      UMI       581
#  237                               Uruguay        UY      URY       858
#  238                            Uzbekistan        UZ      UZB       860
#  239                               Vanuatu        VU      VUT       548
#  240                             Venezuela        VE      VEN       862
#  241                              Viet Nam        VN      VNM       704
#  242                British Virgin Islands        VG      VGB        92
#  243                     US Virgin Islands        VI      VIR       850
#  244                     Wallis and Futuna        WF      WLF       876
#  245                        Western Sahara        EH      ESH       732
#  246                                 Yemen        YE      YEM       887
#  247                                Zambia        ZM      ZMB       894
#  248                              Zimbabwe        ZW      ZWE       716
#
#                  4
#  0    DIALING CODE
#  1              93
#  2             355
#  3             213
#  4           1-684
#  5             376
#  6             244
#  7           1-264
#  8             672
#  9           1-268
#  10             54
#  11            374
#  12            297
#  13             61
#  14             43
#  15            994
#  16          1-242
#  17            973
#  18            880
#  19          1-246
#  20            375
#  21             32
#  22            501
#  23            229
#  24          1-441
#  25            975
#  26            591
#  27            599
#  28            387
#  29            267
#  ..            ...
#  219           255
#  220            66
#  221           670
#  222           228
#  223           690
#  224           676
#  225         1-868
#  226           216
#  227            90
#  228           993
#  229         1-649
#  230           688
#  231           256
#  232           380
#  233           971
#  234            44
#  235             1
#  236             1
#  237           598
#  238           998
#  239           678
#  240            58
#  241            84
#  242         1-284
#  243         1-340
#  244           681
#  245           212
#  246           967
#  247           260
#  248           263
#
#  [249 rows x 5 columns]]
# C:\Users\dsiddine\AppData\Local\Continuum\anaconda3\lib\site-packages\gevent\hub.py:154: UserWarning: libuv only supports millisecond timer resolution; all times less will be set to 1 ms
#   with loop.timer(seconds, ref=ref) as t:

# %%
counrty_df = tables[0]
counrty_df.columns = ['COUNTRY', 'A2 (ISO)', 'A3 (UN)', 'NUM (UN)', 'DIALING CODE']
counrty_df.head()
# Out:
#           COUNTRY  A2 (ISO)  A3 (UN)  NUM (UN)  DIALING CODE
# 0         COUNTRY  A2 (ISO)  A3 (UN)  NUM (UN)  DIALING CODE
# 1     Afghanistan        AF      AFG         4            93
# 2         Albania        AL      ALB         8           355
# 3         Algeria        DZ      DZA        12           213
# 4  American Samoa        AS      ASM        16         1-684
# C:\Users\dsiddine\AppData\Local\Continuum\anaconda3\lib\site-packages\gevent\hub.py:154: UserWarning: libuv only supports millisecond timer resolution; all times less will be set to 1 ms
#   with loop.timer(seconds, ref=ref) as t:

# %%
counrty_df = counrty_df.iloc[1:]
counrty_df = counrty_df.rename(columns = {"COUNTRY":"Country", "A2 (ISO)":"country_codes", "A3 (UN)":"A3 (UN)", "NUM (UN)":
                                          "NUM (UN)", "DIALING CODE":"DIALING CODE" })
counrty_df= counrty_df.drop(columns=["A3 (UN)", "NUM (UN)", "DIALING CODE"])

counrty_df.head()
# Out:
#           Country country_codes
# 1     Afghanistan            AF
# 2         Albania            AL
# 3         Algeria            DZ
# 4  American Samoa            AS
# 5         Andorra            AD
# C:\Users\dsiddine\AppData\Local\Continuum\anaconda3\lib\site-packages\gevent\hub.py:154: UserWarning: libuv only supports millisecond timer resolution; all times less will be set to 1 ms
#   with loop.timer(seconds, ref=ref) as t:

# %%
# merge counrty_df to music_data_df
music_df = music_data_df.merge(counrty_df, how="inner", on =["country_codes", "country_codes"])
music_df.head()
# Out:
#    Position                  Track Name         Artist  Streams  \
# 0         1  Reggaetón Lento (Bailemos)           CNCO    19272
# 1         2                    Chantaje        Shakira    19270
# 2         3   Otra Vez (feat. J Balvin)  Zion & Lennox    15761
# 3         4                Vente Pa' Ca   Ricky Martin    14954
# 4         5                      Safari       J Balvin    14269
#
#                                                  URL        Date  \
# 0  https://open.spotify.com/track/3AEZUABDXNtecAO...  2017-01-01
# 1  https://open.spotify.com/track/6mICuAdrwEjh6Y6...  2017-01-01
# 2  https://open.spotify.com/track/3QwBODjSEzelZyV...  2017-01-01
# 3  https://open.spotify.com/track/7DM4BPaS7uofFul...  2017-01-01
# 4  https://open.spotify.com/track/6rQSrBHf7HlZjtc...  2017-01-01
#
#   country_codes  Country
# 0            EC  Ecuador
# 1            EC  Ecuador
# 2            EC  Ecuador
# 3            EC  Ecuador
# 4            EC  Ecuador
# C:\Users\dsiddine\AppData\Local\Continuum\anaconda3\lib\site-packages\gevent\hub.py:154: UserWarning: libuv only supports millisecond timer resolution; all times less will be set to 1 ms
#   with loop.timer(seconds, ref=ref) as t:

# %%
tracks_df = music_data_df[['Track Name', 'Artist']].groupby(['Track Name', 'Artist']).nunique()
tracks_df = tracks_df[["Track Name","Artist"]].copy()
tracks_df.rename(columns={"Track Name":"track_count","Artist":"art_count"}, inplace=True)
tracks_df = tracks_df.reset_index()
tracks_df.rename(columns={"Track Name":"Track"}, inplace=True)
tracks_df_unique = tracks_df[["Track","Artist"]].copy()
tracks_df_unique.head()
# Out:
#                                        Track          Artist
# 0  "All That Is or Ever Was or Ever Will Be"  Alan Silvestri
# 1               "Read All About It, Pt. III"     Emeli Sandé
# 2                                        #99             JVG
# 3                                     #Askip         Black M
# 4                    #Biziz - feat. Lil Bege         Reynmen
# C:\Users\dsiddine\AppData\Local\Continuum\anaconda3\lib\site-packages\gevent\hub.py:154: UserWarning: libuv only supports millisecond timer resolution; all times less will be set to 1 ms
#   with loop.timer(seconds, ref=ref) as t:

# %%
urls=[]
for index,row in tracks_df_unique.iterrows(): 
    track = row.Track.replace("#","%23")
    artist = row.Artist.replace("#","%23")
    url =  f"http://ws.audioscrobbler.com/2.0/?method=track.getInfo&api_key={key}&artist={artist}&track={track}&format=json"
    urls.append(url)
# Out:
# C:\Users\dsiddine\AppData\Local\Continuum\anaconda3\lib\site-packages\gevent\hub.py:154: UserWarning: libuv only supports millisecond timer resolution; all times less will be set to 1 ms
#   with loop.timer(seconds, ref=ref) as t:

# %%
# A list to hold our things to do via async
async_list = []

for u in urls:
    action_item = grequests.get(u, timeout=1000000)
    async_list.append(action_item)

response = grequests.map(async_list)
# Out:
# C:\Users\dsiddine\AppData\Local\Continuum\anaconda3\lib\site-packages\gevent\hub.py:154: UserWarning: libuv only supports millisecond timer resolution; all times less will be set to 1 ms
#   with loop.timer(seconds, ref=ref) as t:

# %%
response = [x for x in response if x is not None ]
len(response)
# Out:
# 3156
# C:\Users\dsiddine\AppData\Local\Continuum\anaconda3\lib\site-packages\gevent\hub.py:154: UserWarning: libuv only supports millisecond timer resolution; all times less will be set to 1 ms
#   with loop.timer(seconds, ref=ref) as t:

# %%
additional_info = []
row={}

for x in response:
    row ={}
    try:
        row["track"] = x.json()["track"]["name"]
        row["album"] = x.json()["track"]["album"]["title"]
        row["artist"] = x.json()["track"]["artist"]["name"]
        row["genre"] = x.json()["track"]["toptags"]["tag"][0]["name"]
        
        additional_info.append(row)
    except (IndexError,KeyError):
        a=1
additional_info = pd.DataFrame(additional_info)
# Out:
# C:\Users\dsiddine\AppData\Local\Continuum\anaconda3\lib\site-packages\gevent\hub.py:154: UserWarning: libuv only supports millisecond timer resolution; all times less will be set to 1 ms
#   with loop.timer(seconds, ref=ref) as t:

# %%
additional_info.rename(columns = {"artist":"Artist", "genre":"Genre","track":"Track Name"}, inplace=True)
# Out:
# C:\Users\dsiddine\AppData\Local\Continuum\anaconda3\lib\site-packages\gevent\hub.py:154: UserWarning: libuv only supports millisecond timer resolution; all times less will be set to 1 ms
#   with loop.timer(seconds, ref=ref) as t:

# %%
# merge counrty_df to music_data_df
music_df_final = music_df.merge(additional_info, how="inner", on =["Artist","Track Name"])
#music_df.head()
# Out:
# C:\Users\dsiddine\AppData\Local\Continuum\anaconda3\lib\site-packages\gevent\hub.py:154: UserWarning: libuv only supports millisecond timer resolution; all times less will be set to 1 ms
#   with loop.timer(seconds, ref=ref) as t:

# %%
music_df_final.head()
# Out:
#    Position   Track Name        Artist  Streams  \
# 0        10  Shaky Shaky  Daddy Yankee     9612
# 1        16  Shaky Shaky  Daddy Yankee     6974
# 2        21  Shaky Shaky  Daddy Yankee     6854
# 3        23  Shaky Shaky  Daddy Yankee     6700
# 4        21  Shaky Shaky  Daddy Yankee     6594
#
#                                                  URL        Date  \
# 0  https://open.spotify.com/track/58IL315gMSTD37D...  2017-01-01
# 1  https://open.spotify.com/track/58IL315gMSTD37D...  2017-01-02
# 2  https://open.spotify.com/track/58IL315gMSTD37D...  2017-01-03
# 3  https://open.spotify.com/track/58IL315gMSTD37D...  2017-01-04
# 4  https://open.spotify.com/track/58IL315gMSTD37D...  2017-01-05
#
#   country_codes  Country        album      Genre
# 0            EC  Ecuador  Shaky Shaky  Reggaeton
# 1            EC  Ecuador  Shaky Shaky  Reggaeton
# 2            EC  Ecuador  Shaky Shaky  Reggaeton
# 3            EC  Ecuador  Shaky Shaky  Reggaeton
# 4            EC  Ecuador  Shaky Shaky  Reggaeton
# C:\Users\dsiddine\AppData\Local\Continuum\anaconda3\lib\site-packages\gevent\hub.py:154: UserWarning: libuv only supports millisecond timer resolution; all times less will be set to 1 ms
#   with loop.timer(seconds, ref=ref) as t:

# %%
len(music_df_final)
# Out:
# 119917
# C:\Users\dsiddine\AppData\Local\Continuum\anaconda3\lib\site-packages\gevent\hub.py:154: UserWarning: libuv only supports millisecond timer resolution; all times less will be set to 1 ms
#   with loop.timer(seconds, ref=ref) as t:

# %%
music_df_final
# Out:
#         Position                           Track Name            Artist  \
# 0             10                          Shaky Shaky      Daddy Yankee
# 1             16                          Shaky Shaky      Daddy Yankee
# 2             21                          Shaky Shaky      Daddy Yankee
# 3             23                          Shaky Shaky      Daddy Yankee
# 4             21                          Shaky Shaky      Daddy Yankee
# 5             23                          Shaky Shaky      Daddy Yankee
# 6             16                          Shaky Shaky      Daddy Yankee
# 7             16                          Shaky Shaky      Daddy Yankee
# 8             22                          Shaky Shaky      Daddy Yankee
# 9             25                          Shaky Shaky      Daddy Yankee
# 10            25                          Shaky Shaky      Daddy Yankee
# 11            25                          Shaky Shaky      Daddy Yankee
# 12            21                          Shaky Shaky      Daddy Yankee
# 13            19                          Shaky Shaky      Daddy Yankee
# 14            19                          Shaky Shaky      Daddy Yankee
# 15            24                          Shaky Shaky      Daddy Yankee
# 16            26                          Shaky Shaky      Daddy Yankee
# 17            27                          Shaky Shaky      Daddy Yankee
# 18            27                          Shaky Shaky      Daddy Yankee
# 19            25                          Shaky Shaky      Daddy Yankee
# 20            22                          Shaky Shaky      Daddy Yankee
# 21            20                          Shaky Shaky      Daddy Yankee
# 22            27                          Shaky Shaky      Daddy Yankee
# 23            33                          Shaky Shaky      Daddy Yankee
# 24            34                          Shaky Shaky      Daddy Yankee
# 25            36                          Shaky Shaky      Daddy Yankee
# 26            31                          Shaky Shaky      Daddy Yankee
# 27            28                          Shaky Shaky      Daddy Yankee
# 28            28                          Shaky Shaky      Daddy Yankee
# 29            35                          Shaky Shaky      Daddy Yankee
# ...          ...                                  ...               ...
# 119887       147                           To Be Free           L D R U
# 119888       134                           To Be Free           L D R U
# 119889       109                           To Be Free           L D R U
# 119890       133                           To Be Free           L D R U
# 119891       195                           To Be Free           L D R U
# 119892       191                           To Be Free           L D R U
# 119893       190                           To Be Free           L D R U
# 119894       165                           To Be Free           L D R U
# 119895       125                           To Be Free           L D R U
# 119896       184                           To Be Free           L D R U
# 119897       167                           To Be Free           L D R U
# 119898       149                           To Be Free           L D R U
# 119899       104                           To Be Free           L D R U
# 119900       141                           To Be Free           L D R U
# 119901       176                           To Be Free           L D R U
# 119902       176                           To Be Free           L D R U
# 119903       194                           To Be Free           L D R U
# 119904       194                           To Be Free           L D R U
# 119905       189                           To Be Free           L D R U
# 119906       187                           To Be Free           L D R U
# 119907       178                           To Be Free           L D R U
# 119908       195                                  Ubu      Methyl Ethel
# 119909       185                                  Ubu      Methyl Ethel
# 119910       192                                  Ubu      Methyl Ethel
# 119911       181                       Straight Lines       Silverchair
# 119912       192                                Alone             Cyrus
# 119913       165  Don't You Want Me - 2002 - Remaster  The Human League
# 119914        64                            Vasilissa    Eleni Foureira
# 119915        52                            Vasilissa    Eleni Foureira
# 119916        57                            Vasilissa    Eleni Foureira
#
#         Streams                                                URL  \
# 0          9612  https://open.spotify.com/track/58IL315gMSTD37D...
# 1          6974  https://open.spotify.com/track/58IL315gMSTD37D...
# 2          6854  https://open.spotify.com/track/58IL315gMSTD37D...
# 3          6700  https://open.spotify.com/track/58IL315gMSTD37D...
# 4          6594  https://open.spotify.com/track/58IL315gMSTD37D...
# 5          7010  https://open.spotify.com/track/58IL315gMSTD37D...
# 6          8257  https://open.spotify.com/track/58IL315gMSTD37D...
# 7          7811  https://open.spotify.com/track/58IL315gMSTD37D...
# 8          6375  https://open.spotify.com/track/58IL315gMSTD37D...
# 9          5946  https://open.spotify.com/track/58IL315gMSTD37D...
# 10         6385  https://open.spotify.com/track/58IL315gMSTD37D...
# 11         6379  https://open.spotify.com/track/58IL315gMSTD37D...
# 12         7338  https://open.spotify.com/track/58IL315gMSTD37D...
# 13         8386  https://open.spotify.com/track/58IL315gMSTD37D...
# 14         7267  https://open.spotify.com/track/58IL315gMSTD37D...
# 15         6368  https://open.spotify.com/track/58IL315gMSTD37D...
# 16         6270  https://open.spotify.com/track/58IL315gMSTD37D...
# 17         6454  https://open.spotify.com/track/58IL315gMSTD37D...
# 18         6529  https://open.spotify.com/track/58IL315gMSTD37D...
# 19         6966  https://open.spotify.com/track/58IL315gMSTD37D...
# 20         7775  https://open.spotify.com/track/58IL315gMSTD37D...
# 21         7648  https://open.spotify.com/track/58IL315gMSTD37D...
# 22         6214  https://open.spotify.com/track/58IL315gMSTD37D...
# 23         6036  https://open.spotify.com/track/58IL315gMSTD37D...
# 24         5772  https://open.spotify.com/track/58IL315gMSTD37D...
# 25         5453  https://open.spotify.com/track/58IL315gMSTD37D...
# 26         6096  https://open.spotify.com/track/58IL315gMSTD37D...
# 27         7247  https://open.spotify.com/track/58IL315gMSTD37D...
# 28         6477  https://open.spotify.com/track/58IL315gMSTD37D...
# 29         5138  https://open.spotify.com/track/58IL315gMSTD37D...
# ...         ...                                                ...
# 119887    20387  https://open.spotify.com/track/5esMq677iP3YplQ...
# 119888    21109  https://open.spotify.com/track/5esMq677iP3YplQ...
# 119889    25298  https://open.spotify.com/track/5esMq677iP3YplQ...
# 119890    20231  https://open.spotify.com/track/5esMq677iP3YplQ...
# 119891    15420  https://open.spotify.com/track/5esMq677iP3YplQ...
# 119892    16162  https://open.spotify.com/track/5esMq677iP3YplQ...
# 119893    16853  https://open.spotify.com/track/5esMq677iP3YplQ...
# 119894    18789  https://open.spotify.com/track/5esMq677iP3YplQ...
# 119895    22380  https://open.spotify.com/track/5esMq677iP3YplQ...
# 119896    16914  https://open.spotify.com/track/5esMq677iP3YplQ...
# 119897    18715  https://open.spotify.com/track/5esMq677iP3YplQ...
# 119898    20034  https://open.spotify.com/track/5esMq677iP3YplQ...
# 119899    25239  https://open.spotify.com/track/5esMq677iP3YplQ...
# 119900    19495  https://open.spotify.com/track/5esMq677iP3YplQ...
# 119901    17888  https://open.spotify.com/track/5esMq677iP3YplQ...
# 119902    18144  https://open.spotify.com/track/5esMq677iP3YplQ...
# 119903    17163  https://open.spotify.com/track/5esMq677iP3YplQ...
# 119904    16858  https://open.spotify.com/track/5esMq677iP3YplQ...
# 119905    16847  https://open.spotify.com/track/5esMq677iP3YplQ...
# 119906    17295  https://open.spotify.com/track/5esMq677iP3YplQ...
# 119907    16559  https://open.spotify.com/track/5esMq677iP3YplQ...
# 119908    16086  https://open.spotify.com/track/3FEBsU1XGqjwkDf...
# 119909    15927  https://open.spotify.com/track/3FEBsU1XGqjwkDf...
# 119910    16766  https://open.spotify.com/track/3FEBsU1XGqjwkDf...
# 119911    19755  https://open.spotify.com/track/5HBDU0kn4f4hkZM...
# 119912    18613  https://open.spotify.com/track/2mjoR5yNhmRAMDP...
# 119913    35748  https://open.spotify.com/track/3L7RtEcu1Hw3OXr...
# 119914     1062  https://open.spotify.com/track/1IqsmlNCzYflCBM...
# 119915     1388  https://open.spotify.com/track/1IqsmlNCzYflCBM...
# 119916     1153  https://open.spotify.com/track/1IqsmlNCzYflCBM...
#
#               Date country_codes    Country                    album  \
# 0       2017-01-01            EC    Ecuador              Shaky Shaky
# 1       2017-01-02            EC    Ecuador              Shaky Shaky
# 2       2017-01-03            EC    Ecuador              Shaky Shaky
# 3       2017-01-04            EC    Ecuador              Shaky Shaky
# 4       2017-01-05            EC    Ecuador              Shaky Shaky
# 5       2017-01-06            EC    Ecuador              Shaky Shaky
# 6       2017-01-07            EC    Ecuador              Shaky Shaky
# 7       2017-01-08            EC    Ecuador              Shaky Shaky
# 8       2017-01-09            EC    Ecuador              Shaky Shaky
# 9       2017-01-10            EC    Ecuador              Shaky Shaky
# 10      2017-01-11            EC    Ecuador              Shaky Shaky
# 11      2017-01-12            EC    Ecuador              Shaky Shaky
# 12      2017-01-13            EC    Ecuador              Shaky Shaky
# 13      2017-01-14            EC    Ecuador              Shaky Shaky
# 14      2017-01-15            EC    Ecuador              Shaky Shaky
# 15      2017-01-16            EC    Ecuador              Shaky Shaky
# 16      2017-01-17            EC    Ecuador              Shaky Shaky
# 17      2017-01-18            EC    Ecuador              Shaky Shaky
# 18      2017-01-19            EC    Ecuador              Shaky Shaky
# 19      2017-01-20            EC    Ecuador              Shaky Shaky
# 20      2017-01-21            EC    Ecuador              Shaky Shaky
# 21      2017-01-22            EC    Ecuador              Shaky Shaky
# 22      2017-01-23            EC    Ecuador              Shaky Shaky
# 23      2017-01-24            EC    Ecuador              Shaky Shaky
# 24      2017-01-25            EC    Ecuador              Shaky Shaky
# 25      2017-01-26            EC    Ecuador              Shaky Shaky
# 26      2017-01-27            EC    Ecuador              Shaky Shaky
# 27      2017-01-28            EC    Ecuador              Shaky Shaky
# 28      2017-01-29            EC    Ecuador              Shaky Shaky
# 29      2017-01-30            EC    Ecuador              Shaky Shaky
# ...            ...           ...        ...                      ...
# 119887  2017-04-19            AU  Australia               To Be Free
# 119888  2017-04-20            AU  Australia               To Be Free
# 119889  2017-04-21            AU  Australia               To Be Free
# 119890  2017-04-22            AU  Australia               To Be Free
# 119891  2017-04-23            AU  Australia               To Be Free
# 119892  2017-04-24            AU  Australia               To Be Free
# 119893  2017-04-26            AU  Australia               To Be Free
# 119894  2017-04-27            AU  Australia               To Be Free
# 119895  2017-04-28            AU  Australia               To Be Free
# 119896  2017-04-29            AU  Australia               To Be Free
# 119897  2017-05-03            AU  Australia               To Be Free
# 119898  2017-05-04            AU  Australia               To Be Free
# 119899  2017-05-05            AU  Australia               To Be Free
# 119900  2017-05-06            AU  Australia               To Be Free
# 119901  2017-05-09            AU  Australia               To Be Free
# 119902  2017-05-10            AU  Australia               To Be Free
# 119903  2017-05-11            AU  Australia               To Be Free
# 119904  2017-05-17            AU  Australia               To Be Free
# 119905  2017-05-20            AU  Australia               To Be Free
# 119906  2017-05-24            AU  Australia               To Be Free
# 119907  2017-05-27            AU  Australia               To Be Free
# 119908  2017-03-03            AU  Australia  Everything Is Forgotten
# 119909  2017-03-05            AU  Australia  Everything Is Forgotten
# 119910  2017-03-09            AU  Australia  Everything Is Forgotten
# 119911  2017-08-10            AU  Australia             Young Modern
# 119912  2017-08-11            AU  Australia                    Alone
# 119913  2017-12-31            AU  Australia   Dare!/Love and Dancing
# 119914  2017-11-21            GR     Greece                Vasilissa
# 119915  2017-11-22            GR     Greece                Vasilissa
# 119916  2017-11-23            GR     Greece                Vasilissa
#
#               Genre
# 0         Reggaeton
# 1         Reggaeton
# 2         Reggaeton
# 3         Reggaeton
# 4         Reggaeton
# 5         Reggaeton
# 6         Reggaeton
# 7         Reggaeton
# 8         Reggaeton
# 9         Reggaeton
# 10        Reggaeton
# 11        Reggaeton
# 12        Reggaeton
# 13        Reggaeton
# 14        Reggaeton
# 15        Reggaeton
# 16        Reggaeton
# 17        Reggaeton
# 18        Reggaeton
# 19        Reggaeton
# 20        Reggaeton
# 21        Reggaeton
# 22        Reggaeton
# 23        Reggaeton
# 24        Reggaeton
# 25        Reggaeton
# 26        Reggaeton
# 27        Reggaeton
# 28        Reggaeton
# 29        Reggaeton
# ...             ...
# 119887         trap
# 119888         trap
# 119889         trap
# 119890         trap
# 119891         trap
# 119892         trap
# 119893         trap
# 119894         trap
# 119895         trap
# 119896         trap
# 119897         trap
# 119898         trap
# 119899         trap
# 119900         trap
# 119901         trap
# 119902         trap
# 119903         trap
# 119904         trap
# 119905         trap
# 119906         trap
# 119907         trap
# 119908          FM4
# 119909          FM4
# 119910          FM4
# 119911         rock
# 119912      dubstep
# 119913          pop
# 119914  2017 single
# 119915  2017 single
# 119916  2017 single
#
# [119917 rows x 10 columns]
# C:\Users\dsiddine\AppData\Local\Continuum\anaconda3\lib\site-packages\gevent\hub.py:154: UserWarning: libuv only supports millisecond timer resolution; all times less will be set to 1 ms
#   with loop.timer(seconds, ref=ref) as t:
